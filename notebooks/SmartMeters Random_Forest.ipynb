# %% [markdown]
# # Random Forest Technique over Smart Meters Dataset

# %%
import pandas as pd
import numpy as np
from pandas import datetime
import matplotlib.pyplot as plt
import os
# Out:
# <ipython-input-1-011295c32d88>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   from pandas import datetime

# %%
energy = pd.read_csv('energy.csv')
len(energy)
# Out:
# 3536007

# %%
housecount = energy.groupby('day')[['LCLid']].nunique()
housecount.head(10)
# Out:
#             LCLid
# day
# 2011-11-23     13
# 2011-11-24     25
# 2011-11-25     32
# 2011-11-26     41
# 2011-11-27     41
# 2011-11-28     55
# 2011-11-29     63
# 2011-11-30     76
# 2011-12-01     92
# 2011-12-02    100

# %%
energy = energy.groupby('day')[['energy_sum']].sum()
energy = energy.merge(housecount, on = ['day'])
energy = energy.reset_index()
energy
# Out:
#             day    energy_sum  LCLid
# 0    2011-11-23     90.385000     13
# 1    2011-11-24    213.412000     25
# 2    2011-11-25    303.993000     32
# 3    2011-11-26    420.976000     41
# 4    2011-11-27    444.883001     41
# ..          ...           ...    ...
# 824  2014-02-24  52867.660004   4994
# 825  2014-02-25  52330.109999   4995
# 826  2014-02-26  51804.199995   4993
# 827  2014-02-27  52580.878999   4990
# 828  2014-02-28   1056.076000   4987
#
# [829 rows x 3 columns]

# %%
energy.count()
# Out:
# day           829
# energy_sum    829
# LCLid         829
# dtype: int64

# %%
energy.day = pd.to_datetime(energy.day,format='%Y-%m-%d').dt.date
energy['avg_energy'] =  energy['energy_sum']/energy['LCLid']
print("Starting Point of Data at Day Level",min(energy.day))
print("Ending Point of Data at Day Level",max(energy.day))
# Out:
# Starting Point of Data at Day Level 2011-11-23
# Ending Point of Data at Day Level 2014-02-28

# %%
energy.describe()
# Out:
#          energy_sum        LCLid  avg_energy
# count    829.000000   829.000000  829.000000
# mean   43535.325676  4234.539204   10.491862
# std    20550.594031  1789.994799    1.902513
# min       90.385000    13.000000    0.211766
# 25%    34665.436003  4084.000000    8.676955
# 50%    46641.160997  5138.000000   10.516983
# 75%    59755.616996  5369.000000   12.000690
# max    84156.135002  5541.000000   15.964434

# %%
energy.head()
# Out:
#           day  energy_sum  LCLid  avg_energy
# 0  2011-11-23   90.385000     13    6.952692
# 1  2011-11-24  213.412000     25    8.536480
# 2  2011-11-25  303.993000     32    9.499781
# 3  2011-11-26  420.976000     41   10.267707
# 4  2011-11-27  444.883001     41   10.850805

# %%
weather = pd.read_csv('weather_daily_darksky.csv')
weather.head(10)
# Out:
#    temperatureMax temperatureMaxTime  windBearing                 icon  \
# 0           11.96   11-11-2011 23:00          123                  fog
# 1            8.59   11-12-2011 14:00          198    partly-cloudy-day
# 2           10.33   27-12-2011 02:00          225    partly-cloudy-day
# 3            8.07   02-12-2011 23:00          232                 wind
# 4            8.22   24-12-2011 23:00          252  partly-cloudy-night
# 5            7.97   15-12-2011 14:00          234                 wind
# 6           13.19   19-11-2011 14:00          117                  fog
# 7            8.32   16-11-2011 23:00          117                  fog
# 8            9.82   12-12-2011 23:00          221                 wind
# 9            9.71   20-11-2011 14:00          115                  fog
#
#    dewPoint temperatureMinTime  cloudCover  windSpeed  pressure  \
# 0      9.40   11-11-2011 07:00        0.79       3.88   1016.08
# 1      4.49   11-12-2011 01:00        0.56       3.94   1007.71
# 2      5.47   27-12-2011 23:00        0.85       3.54   1032.76
# 3      3.69   02-12-2011 07:00        0.32       3.00   1012.12
# 4      2.79   24-12-2011 07:00        0.37       4.46   1028.17
# 5      2.41   15-12-2011 00:00        0.42       4.71    996.75
# 6      8.12   19-11-2011 23:00        0.26       2.37   1016.80
# 7      5.58   16-11-2011 07:00        0.81       2.36   1017.40
# 8      4.10   12-12-2011 07:00        0.38       5.02   1002.47
# 9      6.62   20-11-2011 08:00        0.41       1.24   1018.82
#
#   apparentTemperatureMinTime  ...  temperatureHigh       sunriseTime  \
# 0           11-11-2011 07:00  ...            10.87  11-11-2011 07:12
# 1           11-12-2011 02:00  ...             8.59  11-12-2011 07:57
# 2           27-12-2011 22:00  ...            10.33  27-12-2011 08:07
# 3           02-12-2011 07:00  ...             7.36  02-12-2011 07:46
# 4           24-12-2011 07:00  ...             7.93  24-12-2011 08:06
# 5           15-12-2011 00:00  ...             7.97  15-12-2011 08:00
# 6           19-11-2011 08:00  ...            13.19  19-11-2011 07:26
# 7           16-11-2011 04:00  ...             8.18  16-11-2011 07:20
# 8           12-12-2011 08:00  ...             8.53  12-12-2011 07:58
# 9           20-11-2011 08:00  ...             9.71  20-11-2011 07:27
#
#    temperatureHighTime       uvIndexTime  \
# 0     11-11-2011 19:00  11-11-2011 11:00
# 1     11-12-2011 14:00  11-12-2011 12:00
# 2     27-12-2011 14:00  27-12-2011 00:00
# 3     02-12-2011 12:00  02-12-2011 10:00
# 4     24-12-2011 15:00  24-12-2011 13:00
# 5     15-12-2011 14:00  15-12-2011 11:00
# 6     19-11-2011 14:00  19-11-2011 10:00
# 7     16-11-2011 14:00  16-11-2011 11:00
# 8     12-12-2011 19:00  12-12-2011 11:00
# 9     20-11-2011 14:00  20-11-2011 10:00
#
#                                              summary  temperatureLowTime  \
# 0                             Foggy until afternoon.    11-11-2011 19:00
# 1                  Partly cloudy throughout the day.    12-12-2011 07:00
# 2                  Mostly cloudy throughout the day.    27-12-2011 23:00
# 3  Partly cloudy throughout the day and breezy ov...    02-12-2011 19:00
# 4                  Mostly cloudy throughout the day.    24-12-2011 19:00
# 5  Partly cloudy throughout the day and breezy in...    16-12-2011 08:00
# 6                     Foggy starting in the evening.    20-11-2011 08:00
# 7                     Foggy starting in the evening.    16-11-2011 19:00
# 8  Partly cloudy throughout the day and breezy st...    13-12-2011 08:00
# 9                              Foggy in the morning.    21-11-2011 02:00
#
#    apparentTemperatureMin  apparentTemperatureMaxTime  \
# 0                    6.48            11-11-2011 23:00
# 1                    0.11            11-12-2011 20:00
# 2                    5.59            27-12-2011 02:00
# 3                    0.46            02-12-2011 12:00
# 4                   -0.51            24-12-2011 23:00
# 5                    1.07            15-12-2011 21:00
# 6                    5.98            19-11-2011 14:00
# 7                    2.93            16-11-2011 23:00
# 8                   -0.64            12-12-2011 23:00
# 9                    4.76            20-11-2011 15:00
#
#   apparentTemperatureLowTime moonPhase
# 0           11-11-2011 19:00      0.52
# 1           12-12-2011 08:00      0.53
# 2           28-12-2011 00:00      0.10
# 3           02-12-2011 19:00      0.25
# 4           24-12-2011 20:00      0.99
# 5           16-12-2011 08:00      0.66
# 6           20-11-2011 08:00      0.79
# 7           16-11-2011 19:00      0.68
# 8           13-12-2011 08:00      0.56
# 9           21-11-2011 01:00      0.82
#
# [10 rows x 32 columns]

# %%
weather.describe()
# Out:
#        temperatureMax  windBearing    dewPoint  cloudCover   windSpeed  \
# count      882.000000   882.000000  882.000000  881.000000  882.000000
# mean        13.660113   195.702948    6.530034    0.477605    3.581803
# std          6.182744    89.340783    4.830875    0.193514    1.694007
# min         -0.060000     0.000000   -7.840000    0.000000    0.200000
# 25%          9.502500   120.500000    3.180000    0.350000    2.370000
# 50%         12.625000   219.000000    6.380000    0.470000    3.440000
# 75%         17.920000   255.000000   10.057500    0.600000    4.577500
# max         32.400000   359.000000   17.770000    1.000000    9.960000
#
#           pressure  apparentTemperatureHigh  visibility    humidity  \
# count   882.000000               882.000000  882.000000  882.000000
# mean   1014.127540                12.723866   11.167143    0.781871
# std      11.073038                 7.279168    2.466109    0.095348
# min     979.250000                -6.460000    1.480000    0.430000
# 25%    1007.435000                 7.032500   10.327500    0.720000
# 50%    1014.615000                12.470000   11.970000    0.790000
# 75%    1021.755000                17.910000   12.830000    0.860000
# max    1040.920000                32.420000   15.340000    0.980000
#
#        apparentTemperatureLow  apparentTemperatureMax     uvIndex  \
# count              882.000000              882.000000  881.000000
# mean                 6.085045               12.929467    2.542565
# std                  6.031967                7.105426    1.832985
# min                 -8.880000               -4.110000    0.000000
# 25%                  1.522500                7.332500    1.000000
# 50%                  5.315000               12.625000    2.000000
# 75%                 11.467500               17.920000    4.000000
# max                 20.540000               32.420000    7.000000
#
#        temperatureLow  temperatureMin  temperatureHigh  \
# count      882.000000      882.000000       882.000000
# mean         7.709841        7.414161        13.542392
# std          4.871004        4.888852         6.260196
# min         -5.640000       -5.640000        -0.810000
# 25%          3.990000        3.705000         9.212500
# 50%          7.540000        7.100000        12.470000
# 75%         11.467500       11.277500        17.910000
# max         20.540000       20.540000        32.400000
#
#        apparentTemperatureMin   moonPhase
# count              882.000000  882.000000
# mean                 5.738039    0.500930
# std                  6.048746    0.287022
# min                 -8.880000    0.000000
# 25%                  1.105000    0.260000
# 50%                  4.885000    0.500000
# 75%                 11.277500    0.750000
# max                 20.540000    0.990000

# %%
weather['day']=  pd.to_datetime(weather['time']) # day is given as timestamp
weather['day']=  pd.to_datetime(weather['day'],format='%Y%m%d').dt.date
# selecting numeric variables
weather = weather[['temperatureMax', 'windBearing', 'dewPoint', 'cloudCover', 'windSpeed',
       'pressure', 'apparentTemperatureHigh', 'visibility', 'humidity',
       'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex',
       'temperatureLow', 'temperatureMin', 'temperatureHigh',
       'apparentTemperatureMin', 'moonPhase','day']]
weather = weather.dropna()

# %%
weather_energy =  energy.merge(weather,on='day')
weather_energy.head(2)
# Out:
#           day  energy_sum  LCLid  avg_energy  temperatureMax  windBearing  \
# 0  2011-11-23      90.385     13    6.952692           10.36          229
# 1  2011-11-24     213.412     25    8.536480           12.93          204
#
#    dewPoint  cloudCover  windSpeed  pressure  ...  visibility  humidity  \
# 0      6.29        0.36       2.04   1027.12  ...        8.06      0.93
# 1      8.56        0.41       4.04   1027.22  ...       10.64      0.89
#
#    apparentTemperatureLow  apparentTemperatureMax  uvIndex  temperatureLow  \
# 0                    6.56                   10.36      1.0            8.24
# 1                    7.30                   12.93      1.0            9.71
#
#    temperatureMin  temperatureHigh  apparentTemperatureMin  moonPhase
# 0            3.81            10.36                    2.18       0.94
# 1            8.56            12.93                    7.01       0.97
#
# [2 rows x 21 columns]

# %%
cor_matrix = weather_energy[['avg_energy','temperatureMax','dewPoint', 'cloudCover', 'windSpeed','pressure', 'visibility', 'humidity','uvIndex', 'moonPhase']].corr()
cor_matrix
# Out:
#                 avg_energy  temperatureMax  dewPoint  cloudCover  windSpeed  \
# avg_energy        1.000000       -0.535188 -0.464499    0.153440   0.105354
# temperatureMax   -0.535188        1.000000  0.863306   -0.346295  -0.138677
# dewPoint         -0.464499        0.863306  1.000000   -0.032393  -0.076935
# cloudCover        0.153440       -0.346295 -0.032393    1.000000   0.177538
# windSpeed         0.105354       -0.138677 -0.076935    0.177538   1.000000
# pressure         -0.064016        0.098138 -0.049710   -0.093291  -0.308825
# visibility       -0.150911        0.269981  0.048479   -0.329287   0.286008
# humidity          0.253010       -0.406919  0.058871    0.489087  -0.035645
# uvIndex          -0.467917        0.690925  0.478066   -0.260507  -0.127803
# moonPhase         0.012307       -0.010147 -0.017442   -0.061224   0.005563
#
#                 pressure  visibility  humidity   uvIndex  moonPhase
# avg_energy     -0.064016   -0.150911  0.253010 -0.467917   0.012307
# temperatureMax  0.098138    0.269981 -0.406919  0.690925  -0.010147
# dewPoint       -0.049710    0.048479  0.058871  0.478066  -0.017442
# cloudCover     -0.093291   -0.329287  0.489087 -0.260507  -0.061224
# windSpeed      -0.308825    0.286008 -0.035645 -0.127803   0.005563
# pressure        1.000000   -0.006675 -0.260783  0.067579   0.009226
# visibility     -0.006675    1.000000 -0.585029  0.256727   0.070642
# humidity       -0.260783   -0.585029  1.000000 -0.540002  -0.009321
# uvIndex         0.067579    0.256727 -0.540002  1.000000  -0.009252
# moonPhase       0.009226    0.070642 -0.009321 -0.009252   1.000000

# %%
weather_energy.head(10)
# Out:
#           day   energy_sum  LCLid  avg_energy  temperatureMax  windBearing  \
# 0  2011-11-23    90.385000     13    6.952692           10.36          229
# 1  2011-11-24   213.412000     25    8.536480           12.93          204
# 2  2011-11-25   303.993000     32    9.499781           13.03          243
# 3  2011-11-26   420.976000     41   10.267707           12.96          237
# 4  2011-11-27   444.883001     41   10.850805           13.54          256
# 5  2011-11-28   500.686000     55    9.103382           12.58          190
# 6  2011-11-29   584.317001     63    9.274873           13.47          213
# 7  2011-11-30   669.827000     76    8.813513           11.87          205
# 8  2011-12-11  2774.456002    201   13.803264           15.26          122
# 9  2011-12-12  2591.456000    216   11.997481            9.82          221
#
#    dewPoint  cloudCover  windSpeed  pressure  ...  visibility  humidity  \
# 0      6.29        0.36       2.04   1027.12  ...        8.06      0.93
# 1      8.56        0.41       4.04   1027.22  ...       10.64      0.89
# 2      7.24        0.48       5.02   1024.47  ...       12.38      0.79
# 3      6.96        0.44       5.75   1025.80  ...       13.07      0.81
# 4      5.76        0.42       5.48   1021.11  ...       13.08      0.72
# 5      4.39        0.56       2.34   1022.80  ...       11.84      0.86
# 6      8.61        0.60       6.48   1009.70  ...       12.57      0.82
# 7      5.26        0.31       4.43   1019.43  ...       13.05      0.78
# 8     12.19        0.78       2.50   1024.77  ...        4.83      0.93
# 9      4.10        0.38       5.02   1002.47  ...       12.05      0.84
#
#    apparentTemperatureLow  apparentTemperatureMax  uvIndex  temperatureLow  \
# 0                    6.56                   10.36      1.0            8.24
# 1                    7.30                   12.93      1.0            9.71
# 2                    4.69                   13.03      1.0            7.01
# 3                   11.59                   12.96      1.0           11.59
# 4                    1.31                   13.54      1.0            1.31
# 5                   10.27                   12.58      1.0           10.27
# 6                    3.34                   13.47      1.0            6.34
# 7                    6.23                   11.87      1.0            9.44
# 8                   10.76                   15.26      1.0           10.76
# 9                    2.71                    5.94      1.0            6.88
#
#    temperatureMin  temperatureHigh  apparentTemperatureMin  moonPhase
# 0            3.81            10.36                    2.18       0.94
# 1            8.56            12.93                    7.01       0.97
# 2            7.46            12.27                    4.84       0.01
# 3            7.01            12.96                    4.69       0.05
# 4            4.47            13.54                    2.94       0.08
# 5            1.31            10.27                    1.31       0.12
# 6            6.37            13.47                    3.39       0.15
# 7            6.34            11.87                    3.34       0.19
# 8           11.56            15.26                   11.56       0.55
# 9            3.09             8.53                   -0.64       0.56
#
# [10 rows x 21 columns]

# %%
weather_energy.columns
# Out:
# Index(['day', 'energy_sum', 'LCLid', 'avg_energy', 'temperatureMax',
#        'windBearing', 'dewPoint', 'cloudCover', 'windSpeed', 'pressure',
#        'apparentTemperatureHigh', 'visibility', 'humidity',
#        'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex',
#        'temperatureLow', 'temperatureMin', 'temperatureHigh',
#        'apparentTemperatureMin', 'moonPhase'],
#       dtype='object')

# %% [raw]
# Importing Holidays in dataset

# %%
holiday = pd.read_csv('uk_bank_holidays.csv')
holiday['Bank holidays'] = pd.to_datetime(holiday['Bank holidays'],format='%Y-%m-%d').dt.date
holiday.head(4)
# Out:
#   Bank holidays                                          Type
# 0    2012-12-26                                    Boxing Day
# 1    2012-12-25                                 Christmas Day
# 2    2012-08-27                           Summer bank holiday
# 3    2012-05-06  Queen?s Diamond Jubilee (extra bank holiday)

# %%
weather_energy = weather_energy.merge(holiday, left_on = 'day',right_on = 'Bank holidays',how = 'left')
weather_energy['holiday_ind'] = np.where(weather_energy['Bank holidays'].isna(),0,1)

# %%
weather_energy = weather_energy[:-1]
weather_energy
# Out:
#             day    energy_sum  LCLid  avg_energy  temperatureMax  windBearing  \
# 0    2011-11-23     90.385000     13    6.952692           10.36          229
# 1    2011-11-24    213.412000     25    8.536480           12.93          204
# 2    2011-11-25    303.993000     32    9.499781           13.03          243
# 3    2011-11-26    420.976000     41   10.267707           12.96          237
# 4    2011-11-27    444.883001     41   10.850805           13.54          256
# ..          ...           ...    ...         ...             ...          ...
# 794  2014-02-23  58345.432995   4998   11.673756           11.94          200
# 795  2014-02-24  52867.660004   4994   10.586235           14.23          183
# 796  2014-02-25  52330.109999   4995   10.476498           11.43          202
# 797  2014-02-26  51804.199995   4993   10.375366           11.29          227
# 798  2014-02-27  52580.878999   4990   10.537250           10.31          224
#
#      dewPoint  cloudCover  windSpeed  pressure  ...  apparentTemperatureMax  \
# 0        6.29        0.36       2.04   1027.12  ...                   10.36
# 1        8.56        0.41       4.04   1027.22  ...                   12.93
# 2        7.24        0.48       5.02   1024.47  ...                   13.03
# 3        6.96        0.44       5.75   1025.80  ...                   12.96
# 4        5.76        0.42       5.48   1021.11  ...                   13.54
# ..        ...         ...        ...       ...  ...                     ...
# 794      6.17        0.66       7.10   1010.37  ...                   11.94
# 795      6.03        0.50       5.02   1005.19  ...                   14.23
# 796      5.06        0.62       5.69   1000.65  ...                   11.43
# 797      2.74        0.26       3.82   1012.73  ...                   11.29
# 798      3.08        0.32       4.14   1007.02  ...                   10.31
#
#      uvIndex  temperatureLow  temperatureMin  temperatureHigh  \
# 0        1.0            8.24            3.81            10.36
# 1        1.0            9.71            8.56            12.93
# 2        1.0            7.01            7.46            12.27
# 3        1.0           11.59            7.01            12.96
# 4        1.0            1.31            4.47            13.54
# ..       ...             ...             ...              ...
# 794      1.0            7.99            8.67            11.94
# 795      1.0            8.25            7.99            14.23
# 796      1.0            4.17            6.79            10.31
# 797      2.0            6.01            4.17            11.29
# 798      2.0            3.43            3.93            10.31
#
#      apparentTemperatureMin  moonPhase  Bank holidays  Type  holiday_ind
# 0                      2.18       0.94            NaN   NaN            0
# 1                      7.01       0.97            NaN   NaN            0
# 2                      4.84       0.01            NaN   NaN            0
# 3                      4.69       0.05            NaN   NaN            0
# 4                      2.94       0.08            NaN   NaN            0
# ..                      ...        ...            ...   ...          ...
# 794                    5.53       0.78            NaN   NaN            0
# 795                    5.52       0.82            NaN   NaN            0
# 796                    3.89       0.86            NaN   NaN            0
# 797                    1.67       0.90            NaN   NaN            0
# 798                    1.41       0.93            NaN   NaN            0
#
# [799 rows x 24 columns]

# %%
#weather_energy.set_index('day', inplace=True)
weather_energy['avg_energy'].plot(figsize=(25,10))
# Out:
# <AxesSubplot:>

# %%
weather_energy.columns
# Out:
# Index(['day', 'energy_sum', 'LCLid', 'avg_energy', 'temperatureMax',
#        'windBearing', 'dewPoint', 'cloudCover', 'windSpeed', 'pressure',
#        'apparentTemperatureHigh', 'visibility', 'humidity',
#        'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex',
#        'temperatureLow', 'temperatureMin', 'temperatureHigh',
#        'apparentTemperatureMin', 'moonPhase', 'Bank holidays', 'Type',
#        'holiday_ind'],
#       dtype='object')

# %%
y = weather_energy['avg_energy'].values
X = weather_energy[['temperatureMax',
       'windBearing', 'dewPoint', 'cloudCover', 'windSpeed', 'pressure',
       'apparentTemperatureHigh', 'visibility', 'humidity',
       'apparentTemperatureLow', 'apparentTemperatureMax', 'uvIndex',
       'temperatureLow', 'temperatureMin', 'temperatureHigh',
       'apparentTemperatureMin', 'moonPhase','holiday_ind']].values
X.shape
# Out:
# (799, 18)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X = sc_X.fit_transform(X.reshape(-1,18))
y = sc_y.fit_transform(y.reshape(-1,1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.05)
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train.reshape(-1,18), y_train.reshape(-1,1))
# Out:
# <ipython-input-23-61a8a0f130d0>:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(X_train.reshape(-1,18), y_train.reshape(-1,1))
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred = regressor.predict(X_test.reshape(-1,18))
y_pred
# Out:
# array([ 0.63784846,  0.24445288, -0.10571815,  1.11280909, -0.64380996,
#         0.93837301,  0.33120261, -0.31456432,  0.3796043 , -0.17263095,
#         1.9017425 ,  0.64554645,  0.91255753, -0.6077246 , -0.13821469,
#        -0.59050541,  0.06183446, -0.05365541, -0.19404955, -0.97476626,
#         0.40040658, -0.66219355, -0.10297668, -0.19040609, -0.61695933,
#        -0.52850643,  1.48343298,  0.73537131,  0.77641229,  1.15052753,
#        -0.088423  ,  0.17636747,  0.22392271,  0.21912748,  0.49058423,
#         0.19207284,  0.67566138,  1.89400116, -0.93033351, -0.02406945])

# %%
y_pred = sc_y.inverse_transform(y_pred)
y_test = sc_y.inverse_transform(y_test)

# %%
y_test = y_test.reshape(40)
y_test
# Out:
# array([12.10334379, 11.00587449, 11.13694442, 11.72236035,  8.27297732,
#         9.33753929, 12.3970394 ,  8.13002028,  9.53820857,  7.99932283,
#        13.52520703, 11.03170574, 11.27902712, 10.66067951,  9.06756384,
#         9.99995319, 10.33611542,  8.39453338, 12.31758468, 12.15904277,
#        10.8669426 , 11.6371062 ,  9.10338181,  9.14762852,  8.01731807,
#         8.11672646, 15.29555344, 11.76754962, 13.0950582 , 12.46528491,
#         9.77831395, 12.57215257,  9.76319796, 11.59420254,  8.36260029,
#        10.26770731, 11.96080762, 14.9769064 ,  7.27615558,  8.85496333])

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 2.1695241806544767

# %%
rmspe = np.sqrt(np.mean(np.square(((y_test - y_pred) / y_test)), axis=0))*100
rmspe
# Out:
# 14.998977159261692

# %%
df = pd.DataFrame({'Real Values':y_test.reshape(-1), 'Predicted Values':y_pred.reshape(-1)})
df
# Out:
#     Real Values  Predicted Values
# 0     12.103344         11.666954
# 1     11.005874         10.925622
# 2     11.136944         10.265745
# 3     11.722360         12.561990
# 4      8.272977          9.251741
# 5      9.337539         12.233275
# 6     12.397039         11.089097
# 7      8.130020          9.872186
# 8      9.538209         11.180307
# 9      7.999323         10.139651
# 10    13.525207         14.048690
# 11    11.031706         11.681460
# 12    11.279027         12.184627
# 13    10.660680          9.319742
# 14     9.067564         10.204507
# 15     9.999953          9.352191
# 16    10.336115         10.581488
# 17     8.394533         10.363854
# 18    12.317585         10.099289
# 19    12.159043          8.628073
# 20    10.866943         11.219508
# 21    11.637106          9.217099
# 22     9.103382         10.270911
# 23     9.147629         10.106155
# 24     8.017318          9.302340
# 25     8.116726          9.469024
# 26    15.295553         13.260410
# 27    11.767550         11.850730
# 28    13.095058         11.928070
# 29    12.465285         12.633068
# 30     9.778314         10.298337
# 31    12.572153         10.797319
# 32     9.763198         10.886934
# 33    11.594203         10.877898
# 34     8.362600         11.389443
# 35    10.267707         10.826915
# 36    11.960808         11.738210
# 37    14.976906         14.034102
# 38     7.276156          8.711804
# 39     8.854963         10.419607

# %%
df.plot(figsize=(20,10))
plt.title('Random Forest Technique')
plt.xlabel('Observations')
plt.ylabel('Average Energy')
plt.savefig('Random_Forest_pred.png')
plt.show()
